# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\49170\Documents\FAU\Diehl Seminar\results\prefixlog.csv")

# %%
data
# Out:
#                     workplace_number pcb_serial_number_str  \
# 0                  Testing(L3150101)          ALR304343350
# 1                 Assembly(L3010101)          ALR304348240
# 2                 Assembly(L3010101)          ALR334354360
# 3                  Testing(L3150101)          ALR304343910
# 4                 Assembly(L3010101)          ALR304349000
# ...                              ...                   ...
# 4712612  Soldering Heating(L3080101)       ALW276247820_20
# 4712613          Soldering(L3080102)       ALW276247820_20
# 4712614         Inspection(L3090101)       ALW276247820_20
# 4712615           Assembly(L3095101)       ALW276247820_20
# 4712616             Repair(L3090102)       ALW276247820_20
#
#         production_order_number article_number          insert_date  \
# 0                       52428D1        87788JJ  2022-01-13 00:22:14
# 1                       52428D1        87788JJ  2022-01-13 00:24:30
# ...
